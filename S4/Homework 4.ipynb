# %% [markdown]
# # Практическое задание к 4 семинару (Непрерывная случайная величина)
# ## Задание 1
# ### Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# ### Найдите ее среднее значение и дисперсию.
#
# M(x) = $\frac{1}{n}\sum x_i$
#
# M(x) = $\frac{1}{2}(200 + 800) = 500$
#
# D(x) = $\frac{\sum (x_i - x_{ср})^2}{m}$
#
# D(x) = $\frac{(200 - 500)^2 + (500 - 500)^2 + (800 - 500)^2}{3} = 30000$
#
# **Ответ: M(x) = 500, D(x) = 30000**

# %% [markdown]
# ## Задача 2
# ### О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# ### Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# ### Если да, найдите ее.
#
# $D(x) = 0.2$
#
# $a = 0.5$
#
# $0.2 = \frac{(b - 0.5)^2}{12}$
#
# $b = 2.05$
#
# **Ответ: 2,05**

# %% [markdown]
# ## Задание 3
# ### Непрерывная случайная величина X распределена нормально и задана плотностью распределения
#
# $f(x) = (1 / (4 * sqrt(2pi))) * exp((-(x+2)**2) / 32)$
#
# Найдите:
#
# #### а). M(X)
#
# $M(x) = -2$
#
# #### б). D(X)
#
# $D(x) = 16$
#
# #### в). std(X) (среднее квадратичное отклонение)
#
# $\sigma = 4$
#
# **Ответ:**
#
# **а) -2**
#
# **б) 16**
#
# **в) 4**

# %% [markdown]
# ### Задание 4
# #### Рост взрослого населения города X имеет нормальное распределение.
# #### Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# #### Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
#
# **а). больше 182 см**
#
# $z = \frac{182-174}{8} = 1$
#
# По таблице накопленного нормального распределения находим вероятность
#
# p = 0.8413
#
# p = 1 - 0.8413 = 0,1587
#
# **б). больше 190 см**
#
# $z = \frac{190-174}{8} = 2$
#
# По таблице накопленного нормального распределения находим вероятность но для -2
#
# p = 0.0228
#
# **в). от 166 см до 190 см**
#
# $z_1 = \frac{190-174}{8} = 2$
#
# $z_2 = \frac{166-174}{8} = -1$
#
# По таблице накопленного нормального распределения находим вероятность
#
# $p_1 = 0.9772$
#
# $p_2 = 0.1587$
#
# $p = p_1 - p_2 = 0.9772 - 0.1587 = 0.8185$
#
# **г). от 166 см до 182 см**
#
# Так как это в рамках отклонения равное среднему квадратичному отклонению то р = 68%
#
# **д). от 158 см до 190 см**
#
# Так как это в рамках отклонения равное двум среднем квадратичным отклонениям то р = 95,4%
#
# **е). не выше 150 см или не ниже 190 см**
#
# $z_1 = \frac{150-174}{8} = -3$
#
# $z_2 = \frac{190-174}{8} = 2$
#
# По таблице накопленного нормального распределения находим вероятность
#
# $p_1 = 0.0013$
#
# $p_2 = 1 - 0.9772 = 0,0228$
#
# $p = 0.0013 + 0,0228 = 0.0241$
#
# **ё). не выше 150 см или не ниже 198 см**
#
# $z_1 = \frac{150-174}{8} = -3$
#
# $z_2 = \frac{198-174}{8} = 3$
#
# По таблице накопленного нормального распределения находим вероятность
#
# $p_1 = 0.0013$
#
# $p_2 = 0.0013$
#
# $p = p_1 + p_2 = 0.0013 + 0.0013 = 0.0026$
#
# **ж). ниже 166 см.**
#
# $z = \frac{166-174}{8} = -1$
#
# По таблице накопленного нормального распределения находим вероятность
#
# $p = 0.1587$
#
# **Ответ:**
#
# **а) 0,1587**
#
# **б) 0.0228**
#
# **в) 0.8185**
#
# **г) 68%**
#
# **д) 95,4%**
#
# **е) 0.0241**
#
# **ё) 0.0026**
#
# **ж) 0.1587**

# %% [markdown]
# ### Задание 5
# #### На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см,
# #### от математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?
#
# $D(x) = 25$
#
# $\sigma = 5$
#
# $\frac{178 - 190}{5} = 2.4$
#
# **Ответ: 2.4**
