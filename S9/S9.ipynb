# %%
import numpy as np
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x1 = np.array([30, 30, 40, 40])
y1 = np.array([37, 47, 50, 60])
coef = np.corrcoef(x1,y1)

plt.scatter(x1,y1)
plt.title(f'r= {coef}')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x1=x1.reshape(-1,1)
x1
# Out:
# array([[30],
#        [30],
#        [40],
#        [40]])

# %%
model = LinearRegression()
model.fit(x1, y1)
r_sq = model.score(x1, y1)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
plt.scatter(x1, y1)
plt.plot(x1,3+1.3*x1)
plt.show()
# Out:
# coefficient of determination: 0.6282527881040892
# intercept: 3.0
# slope: [1.3]

# %%
x2 = np.array([30, 30, 40, 40, 20, 20, 50, 50])
y2 = np.array([37, 47, 50, 60, 25, 35, 62, 72])
coef = np.corrcoef(x2,y2)

plt.scatter(x2,y2)
plt.title(f'r= {coef}')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x2=x2.reshape(-1,1)
model = LinearRegression()
model.fit(x2, y2)
r_sq = model.score(x2, y2)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
plt.scatter(x2, y2)
plt.plot(x2,5.1+1.24*x2)
plt.show()
# Out:
# coefficient of determination: 0.8846950517836594
# intercept: 5.1000000000000085
# slope: [1.24]

# %%
x3 = np.array([30,30,40, 40, 20, 20, 50, 50, 10, 10, 60, 60])
y3 = np.array([37, 47, 50, 60, 25, 35, 62, 72, 13, 23, 74, 84])
coef = np.corrcoef(x3,y3)

plt.scatter(x3,y3)
plt.title(f'r= {coef}')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x3=x3.reshape(-1,1)
model = LinearRegression()
model.fit(x3, y3)
r_sq = model.score(x3, y3)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
plt.scatter(x3, y3)
plt.plot(x3,5.6+1.23*x3)
plt.show()
# Out:
# coefficient of determination: 0.9459101071621309
# intercept: 5.6000000000000085
# slope: [1.22571429]

# %%
x4 = np.array([10,8, 13, 9,11,14, 6,4,12, 7,5])
y4 = np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68 ])
coef = np.corrcoef(x4,y4)

plt.scatter(x4,y4)
plt.title(f'r= {coef}')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x4=x4.reshape(-1,1)
model = LinearRegression()
model.fit(x4, y4)
r_sq = model.score(x4, y4)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
plt.scatter(x4, y4)
plt.plot(x4,3+0.5*x4)
plt.show()
# Out:
# coefficient of determination: 0.6665424595087748
# intercept: 3.0000909090909094
# slope: [0.50009091]

# %%
y4_res = model.predict(x4)
y4_res
# Out:
# array([ 8.001     ,  7.00081818,  9.50127273,  7.50090909,  8.50109091,
#        10.00136364,  6.00063636,  5.00045455,  9.00118182,  6.50072727,
#         5.50054545])

# %%
res = y4 - y4_res
res
# Out:
# array([ 0.039     , -0.05081818, -1.92127273,  1.30909091, -0.17109091,
#        -0.04136364,  1.23936364, -0.74045455,  1.83881818, -1.68072727,
#         0.17945455])

# %%
stats.shapiro(res)
# Out:
# ShapiroResult(statistic=0.9421077966690063, pvalue=0.545586347579956)

# %%
plt.scatter(y4_res, res)

# %%
x3 = np.array([30,30,40, 40, 20, 20, 50, 50, 10, 10, 60, 60])
y3 = np.array([37, 47, 50, 60, 25, 35, 62, 72, 13, 23, 74, 84])
coef = np.corrcoef(x3,y3)

x3=x3.reshape(-1,1)
model = LinearRegression()
model.fit(x3, y3)
r_sq = model.score(x3, y3)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
plt.scatter(x3, y3)
plt.plot(x3,5.6+1.23*x3)
plt.show()
# Out:
# coefficient of determination: 0.9459101071621309
# intercept: 5.6000000000000085
# slope: [1.22571429]

# %%
y3_res = model.predict(x3)
y3_res
# Out:
# array([42.37142857, 42.37142857, 54.62857143, 54.62857143, 30.11428571,
#        30.11428571, 66.88571429, 66.88571429, 17.85714286, 17.85714286,
#        79.14285714, 79.14285714])

# %%
res = y3 - y3_res
res
# Out:
# array([-5.37142857,  4.62857143, -4.62857143,  5.37142857, -5.11428571,
#         4.88571429, -4.88571429,  5.11428571, -4.85714286,  5.14285714,
#        -5.14285714,  4.85714286])

# %%
stats.shapiro(res)
# Out:
# ShapiroResult(statistic=0.6926856637001038, pvalue=0.0007171241450123489)

# %%
plt.scatter(y3_res, res)

# %%
a = np.array([12, 10, 11, 19, 13, 11, 17, 15, 19, 14, 21, 18, 21, 11, 17, 14, 15, 17, 20, 19])

b = np.array([11, 13, 18, 15, 17, 18, 10, 21, 26, 15, 11, 12, 15, 17, 10, 18, 18, 12,21, 20])

stats.mannwhitneyu(a, b)
# Out:
# MannwhitneyuResult(statistic=200.0, pvalue=1.0)

# %%
t = (np.mean(a) - np.mean(b)) / np.sqrt(np.var(a, ddof=1)/len(a) + np.var(b, ddof=1)/len(b))

print(t)
# Out:
# -0.1599663264228627

# %%
stats.ttest_ind(a,b, equal_var= True)
# Out:
# Ttest_indResult(statistic=-0.1599663264228627, pvalue=0.8737549039369696)

# %%
stats.t.ppf(0.8737549039369696/2, 2*len(a))
# Out:
# -0.15991237511991405

# %%
stats.ttest_ind(a, b, alternative='greater', equal_var = True)
# Out:
# Ttest_indResult(statistic=-0.1599663264228627, pvalue=0.5631225480315152)

# %%
stats.ttest_ind(a, b, alternative='less', equal_var = True)
# Out:
# Ttest_indResult(statistic=-0.1599663264228627, pvalue=0.4368774519684848)
